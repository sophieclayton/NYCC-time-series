# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import datetime

matplotlib.rcParams['font.serif'] = "Times New Roman"
matplotlib.rcParams['font.family'] = "serif"
matplotlib.rcParams['font.size'] = '15.0'
matplotlib.rcParams['text.usetex'] = 'True'

# %%
# read in the phytoplankton abundance data 
infile = '../data/taxa_abundance_v0.1.csv'
data = pd.read_csv(infile, sep = ',',parse_dates = ['date'])


datetime_index = pd.DatetimeIndex(data.date.values)
data = data.set_index(datetime_index)

# get the list of columns in the table, which will include all of the species
for t in range(len(data.columns)): print(data.columns[t])
# Out:
# Prorocentrum minimum<Prorocentrum<Prorocentraceae
# pennate 3 temp
# small<detritus
# pennate<Bacillariophyta
# multiple<other
# pennate 6 temp
# flagellar-small-phyto
# small-phyto-temporal
# Cryptomonas sp.
# Amphiprora
# Heterocapsa triquetra<Heterocapsa
# Cocconeis sp.
# centric 4 temp
# pennate 1 temp
# detritus
# centric 1 temp
# uncertain
# Euglenales
# Skeletonema costatum
# Gomphonema sp.
# Heterocapsa rotundata
# Chlamydomonas sp.
# Thalassiosira
# Asterionellopsis glacialis<Asterionellopsis
# Chaetoceros chain
# Karlodinium sp.<Karlodinium<Dinophyceae X
# Cyanophyceae
# pennate 10 temp
# pennate 8 temp
# centric 14 temp
# Heterocapsa 04
# Apedinella
# Strombidium
# Ciliophora
# pennate 4 temp
# dinoflagellate-ix
# Amphidinium sp.<Amphidinium
# Cylindrotheca closterium<Cylindrotheca
# centric 2 temp
# Cerataulina pelagica
# Gyrodinium sp.<Gyrodinium
# Gymnodinium 02
# fungal
# pennate 11 temp
# thalassiosira chain
# pennate 5 temp
# pennate 9 temp
# Melosira sp.
# pennate 2 temp
# Grammatophora
# Heterocapsa 01
# centric 7 temp
# centric 6 temp
# Dactyliosolen fragilissimus
# dinoflagellate-v
# fiber<detritus
# Chaetoceros sp.
# Desmidium
# Corythodinium sp.
# big<egg
# Warnowiaceae<Gymnodiniales
# Heterocapsa triquetra<Heterocapsa 01
# badfocus<artefact
# dinoflagellate-xii
# centric 3 temp
# Phormidium
# Pyramimonas sp.
# Chroococcales
# part<other
# centric 5 temp
# dinoflagellate-x
# Thalassionema nitzschioides<Thalassionema
# dinoflagellate-viii
# Chrysochromulina
# Tabellaria
# Paralia sulcata<Paralia
# dinoflagellate-iii
# Amylax<Gonyaulacaceae
# Gyrosigma fasciola
# Mesodinium
# Prorocentrum micans<Prorocentrum
# spore
# Coscinodiscophyceae
# Gymnodinium 03
# Leptocylindrus minimus
# Scenedesmus sp.
# Pyramimonas
# Diplopsalid group
# Bacillaria
# Oocystis
# dinoflagellate-vi
# Pseudo-nitzschia sp.
# Rotifera
# Guinardia delicatula
# Pterosperma
# Actinoptychus sp.
# Cyclotella
# Rhizosolenia sp.
# Gonyaulax spinifera<Gonyaulax
# Prorocentrum 01
# dinoflagellate-iv
# Dictyosphaerium sp.
# Delphineis
# Ebria tripartita
# Chroomonas
# Achnanthes
# Scrippsiella sp.<Scrippsiella
# dinoflagellate-ii
# Crucigenia
# Cerataulina 2 temp
# Tintinnida
# Leptocylindrus danicus
# Dinophysiaceae<3
# dinoflagellate-i
# Tetrastrum
# Heterocapsa 02
# Amphidinium carterae<Amphidinium
# Gymnodinium 01
# Ankistrodesmus falcatus
# Synedra sp.
# Campylosira
# Dinophysis
# Quadrigula
# Ankistrodesmus sp.
# Merismopedia
# Pediastrum sp.
# Chlorophyceae<Chlorophyta
# Tintinnopsis
# Arthropoda
# Chlorophyta<Viridiplantae
# Corethron
# dinoflagellate-vii
# Pseudanabaena
# Ditylum brightwellii<Ditylum
# pollen
# Amphora
# dinoflagellate-xi
# sample_id
# date
# vol_ml

# %%
# before we can plot the data, we need to calculate abundances and then get the daily mean and standard deviation of 
# those abundances

dmean = data.resample('D').mean()
dstd = data.resample('D').std()

# now pick a species, s,  that you want to plot the abundance for
s = 'Heterocapsa triquetra<Heterocapsa'

plt.plot(dmean.index, dmean[s])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-453f0da2178c> in <module>
#       2 # those abundances
#       3
# ----> 4 dmean = data.resample('D').nanmean()
#       5 dstd = data.resample('D').std()
#       6
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/resample.py in __getattr__(self, attr)
#     105             return self[attr]
#     106
# --> 107         return object.__getattribute__(self, attr)
#     108
#     109     def __iter__(self):
#
# AttributeError: 'DatetimeIndexResampler' object has no attribute 'nanmean'
